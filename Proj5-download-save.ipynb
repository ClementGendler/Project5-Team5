# %% [markdown]
# #### This sheet is for cutting US dataset down to states, and saving state files (to cut down on filesize)

# %%
# imports
import pandas as pd

# %%
# other settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# index = pd.read_csv("https://storage.googleapis.com/covid19-open-data/v2/index.csv")
# index.shape
# Out:
# (20241, 14)

# %%
# index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20241 entries, 0 to 20240
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                20240 non-null  object
#  1   wikidata           18738 non-null  object
#  2   datacommons        3979 non-null   object
#  3   country_code       20240 non-null  object
#  4   country_name       20241 non-null  object
#  5   subregion1_code    19992 non-null  object
#  6   subregion1_name    19992 non-null  object
#  7   subregion2_code    18719 non-null  object
#  8   subregion2_name    18720 non-null  object
#  9   locality_code      30 non-null     object
#  10  locality_name      29 non-null     object
#  11  3166-1-alpha-2     20238 non-null  object
#  12  3166-1-alpha-3     20239 non-null  object
#  13  aggregation_level  20241 non-null  int64
# dtypes: int64(1), object(13)
# memory usage: 2.2+ MB

# %%
# index.to_csv('index_raw.csv')

# %%
data = pd.read_csv('./data/data_us_raw.csv')
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.shape
# Out:
# (969075, 109)

# %%
data.head(5).T
# Out:
#                                                            0  \
# Unnamed: 0                                           4956590
# key                                                       US
# date                                              2020-01-01
# wikidata                                                 Q30
# datacommons                                      country/USA
# country_code                                              US
# country_name                        United States of America
# subregion1_code                                          NaN
# subregion1_name                                          NaN
# subregion2_code                                          NaN
# subregion2_name                                          NaN
# locality_code                                            NaN
# locality_name                                            NaN
# 3166-1-alpha-2                                            US
# ...

# %%
data.info(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 969075 entries, 0 to 969074
# Data columns (total 109 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   Unnamed: 0                          int64
#  1   key                                 object
#  2   date                                object
#  3   wikidata                            object
#  4   datacommons                         object
#  5   country_code                        object
#  6   country_name                        object
#  7   subregion1_code                     object
#  8   subregion1_name                     object
#  9   subregion2_code                     float64
#  10  subregion2_name                     object
#  11  locality_code                       object
#  12  locality_name                       object
#  13  3166-1-alpha-2                      object
#  14  3166-1-alpha-3                      object
# ...

# %%
# data_ca = data.loc[data['subregion1_name'] == 'California']

# %%
# data_ca.shape
# Out:
# (17700, 109)

# %%
# data_ca.to_csv('./data/data_ca_raw.csv')

# %%
# data_colo = data.loc[data['subregion1_name'] == 'Colorado']
# data_colo.shape
# Out:
# (19175, 109)

# %%
# data_colo.to_csv('./data/data_colo_raw.csv')

# %%
# data_oh = data.loc[data['subregion1_name'] == 'Ohio']
# data_oh.shape
# Out:
# (26255, 109)

# %%
# data_oh.to_csv('./data/data_oh_raw.csv')
