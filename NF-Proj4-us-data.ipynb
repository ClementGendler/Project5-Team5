# %%
# https://storage.googleapis.com/covid19-open-data/v2/main.csv

import pandas as pd

# %%
# data = pd.read_csv("https://storage.googleapis.com/covid19-open-data/v2/main.csv")
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (2,3,6,8,9,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('./data_us_raw.csv')
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head().T
# Out:
#                                               0            1            2  \
# key                                          AD           AD           AD
# date                                 2020-01-01   2020-01-02   2020-01-03
# wikidata                                   Q228         Q228         Q228
# datacommons                         country/AND  country/AND  country/AND
# country_code                                 AD           AD           AD
# country_name                            Andorra      Andorra      Andorra
# subregion1_code                             NaN          NaN          NaN
# subregion1_name                             NaN          NaN          NaN
# subregion2_code                             NaN          NaN          NaN
# subregion2_name                             NaN          NaN          NaN
# locality_code                               NaN          NaN          NaN
# locality_name                               NaN          NaN          NaN
# ...

# %%
data['country_name'].value_counts()
# Out:
# Brazil                                          1656720
# United States of America                         969075
# Mexico                                           737795
# Peru                                             560795
# Israel                                           439845
# Colombia                                         341020
# India                                            228035
# Argentina                                        160775
# Netherlands                                      108560
# Chile                                            107085
# Spain                                             92925
# United Kingdom                                    58115
# Italy                                             36875
# France                                            34810
# Canada                                            31270
# Philippines                                       29205
# Czech Republic                                    27140
# ...

# %%
data_us = data.loc[data['country_name'] == 'United States of America']      #.index, inplace=True)

# %%
data_us.head().T
# Out:
#                                                      4956590  \
# key                                                       US
# date                                              2020-01-01
# wikidata                                                 Q30
# datacommons                                      country/USA
# country_code                                              US
# country_name                        United States of America
# subregion1_code                                          NaN
# subregion1_name                                          NaN
# subregion2_code                                          NaN
# subregion2_name                                          NaN
# locality_code                                            NaN
# locality_name                                            NaN
# 3166-1-alpha-2                                            US
# 3166-1-alpha-3                                           USA
# ...

# %%
data_us['subregion1_name'].value_counts()
# Out:
# Texas                       75225
# Georgia                     47495
# Virginia                    39530
# Kentucky                    35695
# Missouri                    34220
# Kansas                      31270
# Illinois                    30385
# North Carolina              29795
# Iowa                        29500
# Tennessee                   28320
# Nebraska                    27730
# Indiana                     27435
# Ohio                        26255
# Minnesota                   25960
# Michigan                    24780
# Mississippi                 24485
# Puerto Rico                 23305
# Oklahoma                    23010
# Arkansas                    22420
# Wisconsin                   21535
# Florida                     20060
# Alabama                     20060
# Pennsylvania                20060
# South Dakota                19765
# Colorado                    19175
# Louisiana                   19175
# New York                    18880
# ...

# %%
data_us.shape
# Out:
# (969075, 108)

# %%
data_us.to_csv('data_us_raw.csv')

# %%
data_us.columns.tolist()
# Out:
# ['key',
#  'date',
#  'wikidata',
#  'datacommons',
#  'country_code',
#  'country_name',
#  'subregion1_code',
#  'subregion1_name',
#  'subregion2_code',
#  'subregion2_name',
#  'locality_code',
#  'locality_name',
#  '3166-1-alpha-2',
#  '3166-1-alpha-3',
#  'aggregation_level',
#  'new_confirmed',
#  'new_deceased',
#  'new_recovered',
#  'new_tested',
#  'total_confirmed',
#  'total_deceased',
#  'total_recovered',
#  'total_tested',
#  'new_hospitalized',
#  'total_hospitalized',
#  'current_hospitalized',
#  'new_intensive_care',
#  'total_intensive_care',
#  'current_intensive_care',
#  'new_ventilator',
#  'total_ventilator',
#  'current_ventilator',
#  'population',
#  'population_male',
#  'population_female',
#  'rural_population',
#  'urban_population',
#  'largest_city_population',
#  'clustered_population',
#  'population_density',
#  'human_development_index',
#  'population_age_00_09',
#  'population_age_10_19',
#  'population_age_20_29',
#  'population_age_30_39',
# ...

# %%
data_us_Covid = data_us[['subregion1_code',
 'subregion1_name',
 'subregion2_code',
 'subregion2_name',
 'locality_code',
 'locality_name',
 '3166-1-alpha-2',
 '3166-1-alpha-3',
 'aggregation_level',
 'new_confirmed',
 'new_deceased',
 'new_recovered',
 'new_tested',
 'total_confirmed',
 'total_deceased',
 'total_recovered',
 'total_tested',
 'new_hospitalized',
 'total_hospitalized',
 'current_hospitalized',
 'new_intensive_care',
 'total_intensive_care',
 'current_intensive_care',
 'new_ventilator',
 'total_ventilator',
 'current_ventilator',
 'population',]]

# %%
data_us_Covid.shape
# Out:
# (969075, 27)

# %%
data_us_Covid.isna()
