# %% [markdown]
# #### The is Neva's starter notebook.  A "scratch pad", so to speak.
# - below is code for creating a dataframe of state-level data  `states_raw.csv`

# %% [markdown]
# https://github.com/GoogleCloudPlatform/covid-19-open-data

# %%
import pandas as pd
# raw = pd.read_csv("https://storage.googleapis.com/covid19-open-data/v2/main.csv", low_memory=False)

# %% [markdown]
# Problem Statement:
# Identify potential Covid hotspots, specifically predict CASES based on government actions, population data, geography, and key health indicators.
# Data sets we will use:
# 1. Covid19 database on GitHub - https://github.com/GoogleCloudPlatform/covid-19-open-data
# 1. Shape files from US Census

# %%
raw.shape
# Out:
# (6072300, 108)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6072300 entries, 0 to 6072299
# Columns: 108 entries, key to relative_humidity
# dtypes: float64(93), int64(1), object(14)
# memory usage: 4.9+ GB

# %%
# raw.to_csv('raw_download.csv')

# %%
# raw = pd.read_csv('raw_download.csv', )     #index_col=False, 

#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (3,4,7,9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
raw.columns.tolist()
# Out:
# ['key',
#  'date',
#  'wikidata',
#  'datacommons',
#  'country_code',
#  'country_name',
#  'subregion1_code',
#  'subregion1_name',
#  'subregion2_code',
#  'subregion2_name',
#  'locality_code',
#  'locality_name',
#  '3166-1-alpha-2',
#  '3166-1-alpha-3',
#  'aggregation_level',
#  'new_confirmed',
#  'new_deceased',
#  'new_recovered',
#  'new_tested',
#  'total_confirmed',
#  'total_deceased',
#  'total_recovered',
#  'total_tested',
#  'new_hospitalized',
#  'total_hospitalized',
#  'current_hospitalized',
#  'new_intensive_care',
#  'total_intensive_care',
#  'current_intensive_care',
#  'new_ventilator',
#  'total_ventilator',
#  'current_ventilator',
#  'population',
#  'population_male',
#  'population_female',
#  'rural_population',
#  'urban_population',
#  'largest_city_population',
#  'clustered_population',
#  'population_density',
#  'human_development_index',
#  'population_age_00_09',
#  'population_age_10_19',
#  'population_age_20_29',
#  'population_age_30_39',
# ...

# %%
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 120)

raw.head(5).T
# Out:
#                                               0            1            2  \
# Unnamed: 0                                    0            1            2
# key                                          AD           AD           AD
# date                                 2020-01-01   2020-01-02   2020-01-03
# wikidata                                   Q228         Q228         Q228
# datacommons                         country/AND  country/AND  country/AND
# country_code                                 AD           AD           AD
# country_name                            Andorra      Andorra      Andorra
# subregion1_code                             NaN          NaN          NaN
# subregion1_name                             NaN          NaN          NaN
# subregion2_code                             NaN          NaN          NaN
# subregion2_name                             NaN          NaN          NaN
# locality_code                               NaN          NaN          NaN
# ...

# %%
raw.shape
# Out:
# (5962245, 109)

# %%
df_state = raw.loc[raw['key'] == 'US_SD']
df_state.shape
# Out:
# (300, 108)

# %%
df_state.head(3)
# Out:
#            key        date wikidata datacommons country_code  \
# 5797500  US_SD  2020-01-01    Q1211    geoId/46           US
# 5797501  US_SD  2020-01-02    Q1211    geoId/46           US
# 5797502  US_SD  2020-01-03    Q1211    geoId/46           US
#
#                      country_name subregion1_code subregion1_name  \
# 5797500  United States of America              SD    South Dakota
# 5797501  United States of America              SD    South Dakota
# 5797502  United States of America              SD    South Dakota
#
#         subregion2_code subregion2_name  ... stringency_index  noaa_station  \
# 5797500             NaN             NaN  ...              0.0  7.265602e+10
# 5797501             NaN             NaN  ...              0.0  7.265602e+10
# 5797502             NaN             NaN  ...              0.0  7.265602e+10
#
#         noaa_distance average_temperature  minimum_temperature  \
# 5797500     26.288294           -2.427778            -9.255556
# ...

# %%
df_state['subregion2_name']
# Out:
# 5797500    NaN
# 5797501    NaN
# 5797502    NaN
# 5797503    NaN
# 5797504    NaN
#           ...
# 5797795    NaN
# 5797796    NaN
# 5797797    NaN
# 5797798    NaN
# 5797799    NaN
# Name: subregion2_name, Length: 300, dtype: object

# %%
# df_state.to_csv('./data/state_sd.csv')
# df_state.to_csv('./data/state_nd.csv')
# df_state.to_csv('./data/state_ks.csv')
# df_state.to_csv('./data/state_ne.csv')
# df_state.to_csv('./data/state_ok.csv')
# df_state.to_csv('./data/state_tx.csv')
# df_state.to_csv('./data/state_nm.csv')
# df_state.to_csv('./data/state_co.csv')
# df_state.to_csv('./data/state_ut.csv')
# df_state.to_csv('./data/state_wy.csv')
# df_state.to_csv('./data/state_nv.csv')
# df_state.to_csv('./data/state_ca.csv')
# df_state.to_csv('./data/state_or.csv')
# df_state.to_csv('./data/state_wa.csv')
# df_state.to_csv('./data/state_id.csv')
# df_state.to_csv('./data/state_mt.csv')

# %%
x = 300 * 15
x
# Out:
# 4500

# %%
state_input = pd.read_csv('./data/state_wy.csv')
state_input.shape
# Out:
# (300, 109)

# %%
state_input.head(3)
# Out:
#    Unnamed: 0    key        date wikidata datacommons country_code  \
# 0     6028500  US_WY  2020-01-01    Q1214    geoId/56           US
# 1     6028501  US_WY  2020-01-02    Q1214    geoId/56           US
# 2     6028502  US_WY  2020-01-03    Q1214    geoId/56           US
#
#                country_name subregion1_code subregion1_name  subregion2_code  \
# 0  United States of America              WY         Wyoming              NaN
# 1  United States of America              WY         Wyoming              NaN
# 2  United States of America              WY         Wyoming              NaN
#
#    ...  stringency_index  noaa_station  noaa_distance average_temperature  \
# 0  ...               0.0  7.267202e+10      78.296276           -2.825397
# 1  ...               0.0  7.267202e+10      78.296276           -1.595238
# 2  ...               0.0  7.267202e+10      78.296276           -3.746032
#
#   minimum_temperature  maximum_temperature  rainfall  snowfall  dew_point  \
# ...

# %%
# concat state-level data into one df, uncomment to revise

# states_raw = pd.concat([state_input, states_raw])
# states_raw.shape
# Out:
# (4800, 109)

# %%
states_raw['subregion1_name'].value_counts()
# Out:
# California      300
# Nebraska        300
# South Dakota    300
# Utah            300
# New Mexico      300
# Oregon          300
# North Dakota    300
# Colorado        300
# Montana         300
# Kansas          300
# Oklahoma        300
# Texas           300
# Washington      300
# Idaho           300
# Wyoming         300
# Nevada          300
# Name: subregion1_name, dtype: int64

# %%
# save state-level data into file, uncomment to revise

# states_raw.to_csv('./data/states_raw.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
states_raw.loc[states_raw['subregion1_code'] == 'CO'].isna().sum()
# Out:
# Unnamed: 0                              0
# key                                     0
# date                                    0
# wikidata                                0
# datacommons                             0
# country_code                            0
# country_name                            0
# subregion1_code                         0
# subregion1_name                         0
# subregion2_code                       300
# subregion2_name                       300
# locality_code                         300
# locality_name                         300
# 3166-1-alpha-2                          0
# 3166-1-alpha-3                          0
# aggregation_level                       0
# new_confirmed                          67
# new_deceased                           67
# new_recovered                         118
# new_tested                             67
# total_confirmed                        66
# total_deceased                         66
# ...
