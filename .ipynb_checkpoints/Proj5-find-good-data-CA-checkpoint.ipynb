# %% [markdown]
# #### This sheet is for finding good available data in CALIFORNIA dataset, or other states?

# %% [markdown]
# Gameplan to get input for rough model
# 1. location
# 1. covid
# 1. health
# 1. govt action
#
# Cleaning steps
# 1. nulls
# 1. datatypes
# 1. ??
#
# EDA steps

# %%
# imports

import pandas as pd

# %%
# other settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# read in CA data
data = pd.read_csv('./data/data_ca_raw.csv')
data.shape
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (17700, 110)

# %%
data.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 110 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   Unnamed: 0                          int64
#  1   Unnamed: 0.1                        int64
#  2   key                                 object
#  3   date                                object
#  4   wikidata                            object
#  5   datacommons                         object
#  6   country_code                        object
#  7   country_name                        object
#  8   subregion1_code                     object
#  9   subregion1_name                     object
#  10  subregion2_code                     float64
#  11  subregion2_name                     object
#  12  locality_code                       object
#  13  locality_name                       object
#  14  3166-1-alpha-2                      object
# ...

# %%
data['subregion2_name'].value_counts()
# Out:
# Alameda County            295
# Madera County             295
# Lake County               295
# Amador County             295
# Placer County             295
# Contra Costa County       295
# Yolo County               295
# Tuolumne County           295
# Modoc County              295
# Sutter County             295
# Solano County             295
# Calaveras County          295
# Napa County               295
# Los Angeles County        295
# San Francisco County      295
# Sonoma County             295
# Plumas County             295
# Orange County             295
# Tehama County             295
# San Bernardino County     295
# Nevada County             295
# Sacramento County         295
# Yuba County               295
# Lassen County             295
# Kings County              295
# Humboldt County           295
# Trinity County            295
# Del Norte County          295
# Tulare County             295
# Kern County               295
# Monterey County           295
# ...

# %% [markdown]
# #### Isolate location info, create lat-long file

# %%
# new = old[['A', 'C', 'D']].copy()

data_geo = data[['open_street_maps',
 'latitude',
 'longitude',
 'elevation',
 'area',
 'rural_area',
 'urban_area']].copy()

# %%
data_geo.shape
# Out:
# (17700, 7)

# %%
data_geo.head()
# Out:
#    open_street_maps  latitude  longitude  elevation      area  rural_area  \
# 0          165475.0      37.0     -120.0      884.0  423970.0         NaN
# 1          165475.0      37.0     -120.0      884.0  423970.0         NaN
# 2          165475.0      37.0     -120.0      884.0  423970.0         NaN
# 3          165475.0      37.0     -120.0      884.0  423970.0         NaN
# 4          165475.0      37.0     -120.0      884.0  423970.0         NaN
#
#    urban_area
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# save to file for each state.  Uncomment to revise.

# data_geo.to_csv('./data/data_ca_geo.csv')
# data_geo.to_csv('./data/data_colo_geo.csv')
# data_geo.to_csv('./data/data_oh_geo.csv')

# %%
data_geo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   open_street_maps  17700 non-null  float64
#  1   latitude          17700 non-null  float64
#  2   longitude         17700 non-null  float64
#  3   elevation         1180 non-null   float64
#  4   area              17700 non-null  float64
#  5   rural_area        0 non-null      float64
#  6   urban_area        0 non-null      float64
# dtypes: float64(7)
# memory usage: 968.1 KB

# %%
data_geo['latitude'].value_counts()
# Out:
# 39.590000    590
# 37.930000    590
# 38.270000    295
# 38.210000    295
# 39.430000    295
# 37.777500    295
# 37.000000    295
# 40.130000    295
# 39.270000    295
# 34.830000    295
# 36.750000    295
# 33.020000    295
# 36.583333    295
# 40.660000    295
# 38.580000    295
# 37.220000    295
# 34.360000    295
# 38.500000    295
# 37.190000    295
# 41.740000    295
# 37.030000    295
# 36.610000    295
# 36.070000    295
# 38.553889    295
# 33.730000    295
# 39.040000    295
# 39.300000    295
# 40.650000    295
# 37.440000    295
# 38.040000    295
# 40.760000    295
# 37.916667    295
# 37.778333    295
# 39.090000    295
# 36.240000    295
# 40.010000    295
# 33.670000    295
# 35.380000    295
# 36.230000    295
# 38.020000    295
# 41.583333    295
# 40.800000    295
# 35.340000    295
# 39.660000    295
# 39.060000    295
# 38.440000    295
# 37.580000    295
# 38.780000    295
# 34.540000    295
# 37.360000    295
# 38.450000    295
# 34.050000    295
# ...

# %% [markdown]
# #### Geographic info -- summary:
# https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-geography.md
#
# California:
# 1. There are 295 observations (rows) for CA-state, and for each county (58 counties)
# 1. Observations are at the day level (Oct 2, Oct 3, etc.), starting Jan 1, 2020
# 1. No data for:  elevation, rural vs. urban designation
# 1. All geo values are floats.
#
# Colorado, Ohio -- TBD

# %%
# create a lat-long file
# new = old[['A', 'C', 'D']].copy()

data_latlong = data[['latitude', 'longitude']].copy()
data_latlong.shape
# Out:
# (17700, 2)

# %%
data_latlong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   17700 non-null  float64
#  1   longitude  17700 non-null  float64
# dtypes: float64(2)
# memory usage: 276.7 KB

# %%
data_latlong.head()
# Out:
#    latitude  longitude
# 0      37.0     -120.0
# 1      37.0     -120.0
# 2      37.0     -120.0
# 3      37.0     -120.0
# 4      37.0     -120.0

# %%
# save latlong data to file for each state. Uncomment to revise.

# data_latlong.to_csv('./data/data_ca_latlong.csv')
# data_latlong.to_csv('./data/data_colo_latlong.csv')
# data_latlong.to_csv('./data/data_oh_latlong.csv')

# %% [markdown]
# #### Covid info -- summary:
# https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-epidemiology.md
#
# California:
# 1. The columns with the most Covid data are
# > new_confirmed, new_recovered, total_confirmed, total_deceased.
# 1. Covid data has several empty columns, include hospitalizations, intensive care, ventilators
#
#
# Colorado, Ohio -- TBD

# %%
data_covid = data[['date', 'new_confirmed',
 'new_deceased',
 'new_recovered',
 'new_tested',
 'total_confirmed',
 'total_deceased',
 'total_recovered',
 'total_tested',
 'new_hospitalized',
 'total_hospitalized',
 'current_hospitalized',
 'new_intensive_care',
 'total_intensive_care',
 'current_intensive_care',
 'new_ventilator',
 'total_ventilator',
 'current_ventilator']].copy()
data_covid.shape
# Out:
# (17700, 18)

# %%
data_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    17700 non-null  object
#  1   new_confirmed           12994 non-null  float64
#  2   new_deceased            12768 non-null  float64
#  3   new_recovered           0 non-null      float64
#  4   new_tested              461 non-null    float64
#  5   total_confirmed         13059 non-null  float64
#  6   total_deceased          12827 non-null  float64
#  7   total_recovered         0 non-null      float64
#  8   total_tested            462 non-null    float64
#  9   new_hospitalized        0 non-null      float64
#  10  total_hospitalized      0 non-null      float64
#  11  current_hospitalized    417 non-null    float64
#  12  new_intensive_care      0 non-null      float64
#  13  total_intensive_care    0 non-null      float64
# ...

# %%
data_covid.head().T
# Out:
#                                  0           1           2           3  \
# date                    2020-01-01  2020-01-02  2020-01-03  2020-01-04
# new_confirmed                  NaN         NaN         NaN         NaN
# new_deceased                   NaN         NaN         NaN         NaN
# new_recovered                  NaN         NaN         NaN         NaN
# new_tested                     NaN         NaN         NaN         NaN
# total_confirmed                NaN         NaN         NaN         NaN
# total_deceased                 NaN         NaN         NaN         NaN
# total_recovered                NaN         NaN         NaN         NaN
# total_tested                   NaN         NaN         NaN         NaN
# new_hospitalized               NaN         NaN         NaN         NaN
# total_hospitalized             NaN         NaN         NaN         NaN
# current_hospitalized           NaN         NaN         NaN         NaN
# ...

# %%
# save Covid data to file for each state.  Uncomment to revise.  

# data_covid.to_csv('./data/data_ca_covid.csv')
# data_covid.to_csv('./data/data_colo_covid.csv')
# data_covid.to_csv('./data/data_oh_covid.csv')

# %% [markdown]
# #### Health info -- summary:
# https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-health.md
#
# California:
# - All columns are empty -- no data.
#
# Colorado, Ohio -- TBD

# %%
data_health = data[['life_expectancy',
 'smoking_prevalence',
 'diabetes_prevalence',
 'infant_mortality_rate',
 'adult_male_mortality_rate',
 'adult_female_mortality_rate',
 'pollution_mortality_rate',
 'comorbidity_mortality_rate',
 'hospital_beds',
 'nurses',
 'physicians',
 'health_expenditure',
 'out_of_pocket_health_expenditure']].copy()
data_health.shape
# Out:
# (17700, 13)

# %%
data_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   life_expectancy                   0 non-null      float64
#  1   smoking_prevalence                0 non-null      float64
#  2   diabetes_prevalence               0 non-null      float64
#  3   infant_mortality_rate             0 non-null      float64
#  4   adult_male_mortality_rate         0 non-null      float64
#  5   adult_female_mortality_rate       0 non-null      float64
#  6   pollution_mortality_rate          0 non-null      float64
#  7   comorbidity_mortality_rate        0 non-null      float64
#  8   hospital_beds                     0 non-null      float64
#  9   nurses                            0 non-null      float64
#  10  physicians                        0 non-null      float64
# ...

# %% [markdown]
# #### Government response info -- summary:
#
# California:
# - Data available at the **state level only**, not by county.
#
# Colorado, Ohio -- TBD

# %%
data_govt = data[[ 'school_closing',
 'workplace_closing',
 'cancel_public_events',
 'restrictions_on_gatherings',
 'public_transport_closing',
 'stay_at_home_requirements',
 'restrictions_on_internal_movement',
 'international_travel_controls',
 'income_support',
 'debt_relief',
 'fiscal_measures',
 'international_support',
 'public_information_campaigns',
 'testing_policy',
 'contact_tracing',
 'emergency_investment_in_healthcare',
 'investment_in_vaccines',
 'stringency_index']].copy()
data_govt.shape
# Out:
# (17700, 18)

# %%
data_govt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   school_closing                      280 non-null    float64
#  1   workplace_closing                   280 non-null    float64
#  2   cancel_public_events                280 non-null    float64
#  3   restrictions_on_gatherings          280 non-null    float64
#  4   public_transport_closing            280 non-null    float64
#  5   stay_at_home_requirements           280 non-null    float64
#  6   restrictions_on_internal_movement   280 non-null    float64
#  7   international_travel_controls       280 non-null    float64
#  8   income_support                      289 non-null    float64
#  9   debt_relief                         280 non-null    float64
#  10  fiscal_measures                     0 non-null      float64
# ...

# %%
data_govt['school_closing'].isna().sum()        #head(120)
# Out:
# 17420

# %%
data_govt['testing_policy'].value_counts()
# Out:
# 2.0    141
# 1.0     89
# 3.0     30
# 0.0     20
# Name: testing_policy, dtype: int64

# %% [markdown]
# #### Mobility info -- summary:
# https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-mobility.md
#
#
# "The data shows how visits to places, such as grocery stores and parks, are changing in each geographic region."
#
#
# "These datasets show how visits and length of stay at different places change compared to a baseline. We calculate these changes using the same kind of aggregated and anonymized data used to show popular times for places in Google Maps.  The data is expressed as a percent change vs. a baseline value for that day of the week:
# - The baseline is the median value, for the corresponding day of the week, during the 5-week period Jan 3–Feb 6, 2020.
# - The datasets show trends over several months with the most recent data representing approximately 2-3 days ago—this is how long it takes to produce the datasets."
#
# There are 6 measures for Mobility.
#
#
# California:
# - Full data for ['mobility_retail_and_recreation'], ['mobility_grocery_and_pharmacy'], ['mobility_workplaces']
# - Data can be imputed for ['mobility_parks'], ['mobility_transit_stations'], [''mobility_residential']
# - Alpine and Sierra counties have no Mobility data.  OK to drop -- these counties are the least populous, with 4,100 residents combined.
#
#
# Colorado, Ohio -- TBD

# %%
data_mobility = data[['subregion2_name', 'mobility_retail_and_recreation',
 'mobility_grocery_and_pharmacy',
 'mobility_parks',
 'mobility_transit_stations',
 'mobility_workplaces',
 'mobility_residential']].copy()
data_mobility.shape
# Out:
# (17700, 7)

# %%
data_mobility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   subregion2_name                 17110 non-null  object
#  1   mobility_retail_and_recreation  12512 non-null  float64
#  2   mobility_grocery_and_pharmacy   12012 non-null  float64
#  3   mobility_parks                  10107 non-null  float64
#  4   mobility_transit_stations       9930 non-null   float64
#  5   mobility_workplaces             13387 non-null  float64
#  6   mobility_residential            10950 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 968.1+ KB

# %%
data_mobility.describe()
# Out:
#        mobility_retail_and_recreation  mobility_grocery_and_pharmacy  \
# count                    12512.000000                   12012.000000
# mean                       -23.548114                      -2.721112
# std                         20.130481                      13.690185
# min                       -100.000000                     -68.000000
# 25%                        -37.000000                     -11.000000
# 50%                        -25.000000                      -4.000000
# 75%                        -11.000000                       5.000000
# max                        113.000000                     114.000000
#
#        mobility_parks  mobility_transit_stations  mobility_workplaces  \
# count    10107.000000                9930.000000         13387.000000
# mean        11.234392                 -24.487412           -28.619183
# std         44.461950                  26.839730            16.850129
# ...

# %%
data_mobility.groupby('subregion2_name').mean()
# Out:
#                         mobility_retail_and_recreation  \
# subregion2_name
# Alameda County                              -40.004082
# Alpine County                                      NaN
# Amador County                                -8.981395
# Butte County                                -21.416327
# Calaveras County                            -24.990741
# Colusa County                               -10.800000
# Contra Costa County                         -32.963265
# Del Norte County                              8.935829
# El Dorado County                            -19.885714
# Fresno County                               -22.648980
# Glenn County                                -10.904762
# Humboldt County                             -25.873469
# Imperial County                             -37.906122
# Inyo County                                  -9.108696
# Kern County                                 -19.428571
# Kings County                                -15.518367
# ...

# %%
data_mobility.to_csv('./data/data_ca_mobility.csv')

# %% [markdown]
# #### Population and Age info -- summary:
# https://github.com/GoogleCloudPlatform/covid-19-open-data/blob/main/docs/table-demographics.md
#
#
# California:
# - Full data on Popluation (total, male, female), and age ranges
# - No data for the columns below, thus they were omitted from the dataslice
# 'rural_population',
#  'urban_population',
#  'largest_city_population',
#  'clustered_population',
#  'population_density',
#  'human_development_index'
# 'gdp',
#  'gdp_per_capita',
#  'human_capital_index'
#
# Colorado, Ohio -- TBD

# %%
data_demo = data[['subregion2_name', 'population',
 'population_male',
 'population_female',
 'population_age_00_09',
 'population_age_10_19',
 'population_age_20_29',
 'population_age_30_39',
 'population_age_40_49',
 'population_age_50_59',
 'population_age_60_69',
 'population_age_70_79',
 'population_age_80_89',
 'population_age_90_99',
 'population_age_80_and_older']].copy()
data_demo.shape
# Out:
# (17700, 15)

# %%
data_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17700 entries, 0 to 17699
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   subregion2_name              17110 non-null  object
#  1   population                   17700 non-null  float64
#  2   population_male              17700 non-null  float64
#  3   population_female            17700 non-null  float64
#  4   population_age_00_09         17700 non-null  float64
#  5   population_age_10_19         17700 non-null  float64
#  6   population_age_20_29         17700 non-null  float64
#  7   population_age_30_39         17700 non-null  float64
#  8   population_age_40_49         17700 non-null  float64
#  9   population_age_50_59         17700 non-null  float64
#  10  population_age_60_69         17700 non-null  float64
#  11  population_age_70_79         17700 non-null  float64
# ...

# %%
data_demo.describe()
# Out:
#          population  population_male  population_female  population_age_00_09  \
# count  1.770000e+04     1.770000e+04       1.770000e+04          1.770000e+04
# mean   1.323081e+06     6.742144e+05       6.844376e+05          1.722886e+05
# std    5.129107e+06     2.672865e+06       2.724801e+06          6.903547e+05
# min    1.111000e+03     6.060000e+02       5.050000e+02          9.200000e+01
# 25%    5.190225e+04     2.669200e+04       2.521025e+04          4.900750e+03
# 50%    2.035780e+05     9.998600e+04       1.035920e+05          2.519150e+04
# 75%    7.889368e+05     3.900208e+05       3.953178e+05          8.315575e+04
# max    3.914482e+07     2.046806e+07       2.085654e+07          5.297960e+06
#
#        population_age_10_19  population_age_20_29  population_age_30_39  \
# count          1.770000e+04          1.770000e+04          1.770000e+04
# mean           1.791144e+05          2.026431e+05          1.942197e+05
# ...

# %%
# save age and population data to file, uncomment to revise

# data_demo.to_csv('./data/data_ca_demo.csv')

# %% [markdown]
# ### Conclusions:
# #### It appears that CA has good data for Mobility, Total Population, and Age Ranges.
# #### For Government Response, data is available at state level only.
#
# Suggest pulling Govt Response data for "western" states:
# key  |  wikidata  |  datacommons
# - Montana == US_MT  |  Q1212  |  geoId/30
# - Idaho == US_ID  |  Q1221  |  geoId/16
# - Washington US_WA  |  Q1223  |  geoId/53
# - Oregon == US_OR  |  Q824  |  geoId/41
# - California == US_CA  |  Q99  |  geoId/06
# - Arizona == US_AZ  |  Q816  |  geoId/04
# - Nevada == US_NV  |  Q1227  |  geoId/32
# - Wyoming == US_WY  |  Q1214  |  geoId/56
# - Utah == US_UT  |  Q829  |  geoId/49
# - Colorado == US_CO  |  Q1261  |  geoId/08
# - New Mexico == US_NM  |  Q1522  |  geoId/35
# - Texas == US_TX  |  Q1439  |  geoId/48
# - Oklahoma == US_OK  |  Q1649  |  geoId/40
# - Nebraska == US_NE  |  Q1553  |  geoId/31
# - Kansas == US_KS  |  Q1558  |  geoId/20
# - North Dakota == US_ND  |  Q1207  |  geoId/38
# - South Dakota == US_SD  |  Q1211  |  geoId/46
#
# Otherwise, suggest using Mobility to look at CA states (along with population and age demographics)

# %%
# data_ca = pd.read_csv('./data/data_ca_raw.csv')
# data_ca.shape
# Out:
# /Users/nevochka/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (17700, 110)

# %%
data_ca.isnull().sum()
# Out:
# Unnamed: 0                                0
# Unnamed: 0.1                              0
# key                                       0
# date                                      0
# wikidata                                  0
# datacommons                             295
# country_code                              0
# country_name                              0
# subregion1_code                           0
# subregion1_name                           0
# subregion2_code                         590
# subregion2_name                         590
# locality_code                         17405
# locality_name                         17405
# 3166-1-alpha-2                            0
# 3166-1-alpha-3                            0
# aggregation_level                         0
# new_confirmed                          4706
# new_deceased                           4932
# new_recovered                         17700
# new_tested                            17239
# ...
